# %% [markdown]
# # Simple Question-Answering Agent
# My implementation based on the LangChain + OpenAI pattern.

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

load_dotenv(dotenv_path=r"C:\Users\dylan\OneDrive\Desktop\02_simple_question_answering_agent\.env")
print("Environment loaded ✅")
# Out:
# Environment loaded ✅

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    max_tokens=1000,
    temperature=0,
    api_key=os.getenv("OPENAI_API_KEY")
)
print("LLM initialized ✅")
# Out:
# Key found: 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

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    max_tokens=1000,
    temperature=0,
    api_key=os.getenv("OPENAI_API_KEY")
)
print("LLM initialized ✅")
# Out:
# LLM initialized ✅

# %%
template = """
You are a helpful AI assistant. Your task is to answer the user's question to the best of your ability.

User's question: {question}

Please provide a clear and concise answer:
"""

prompt = PromptTemplate(template=template, input_variables=["question"])
print("Prompt template defined ✅")
# Out:
# Prompt template defined ✅

# %%
qa_chain = prompt | llm
print("QA chain created ✅")
# Out:
# QA chain created ✅

# %%
def get_answer(question):
    response = qa_chain.invoke({"question": question}).content
    return response

# %%
question = "What is the capital of France?"
answer = get_answer(question)
print(f"Question: {question}")
print(f"Answer: {answer}")
# Out:
# Question: What is the capital of France?
# Answer: The capital of France is Paris.
